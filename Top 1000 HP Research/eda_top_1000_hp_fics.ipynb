# %% [markdown]
# # Exploratory Data Analysis of the Top 1000 Harry Potter Fanfictions on AO3

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import data and set all the indices to the work_id
top_1000_hp_fics = pd.read_csv('top_1000_hp_fics_clean.csv', index_col='work_id')
hp_characters_bool = pd.read_csv('top_1000_hp_characters_bool.csv', index_col='Unnamed: 0')
hp_fandoms_bool = pd.read_csv('top_1000_hp_fandoms_bool.csv', index_col='Unnamed: 0')
hp_freeforms_bool = pd.read_csv('top_1000_hp_freeforms_bool.csv', index_col='Unnamed: 0')
hp_relationships_bool = pd.read_csv('top_1000_hp_relationships_bool.csv', index_col='Unnamed: 0')
hp_slash_categories_bool = pd.read_csv('top_1000_hp_slash_categories_bool.csv', index_col='Unnamed: 0')
hp_warnings_bool = pd.read_csv('top_1000_hp_warnings_bool.csv', index_col='Unnamed: 0')

# %%
# Make sure they all loaded in okay
print(top_1000_hp_fics.head())
print(hp_characters_bool.head())
print(hp_fandoms_bool.head())
print(hp_freeforms_bool.head())
print(hp_relationships_bool.head())
print(hp_slash_categories_bool.head())
print(hp_warnings_bool.head())
# Out:
#                Unnamed: 0       user_id                                 title  \
# work_id
# work_10057010           0  user-2878526                   All the Young Dudes
# work_234222             1     user-6004  Then Comes a Mist and a Weeping Rain
# work_14454174           2  user-3861138                              Manacled
# work_3101099            3   user-276513            The Standard You Walk Past
# work_12006417           4    user-53377                  survival is a talent
#
#                               rating  \
# work_id
# work_10057010                 Mature
# work_234222                 Explicit
# work_14454174               Explicit
# work_3101099                  Mature
# work_12006417  Teen And Up Audiences
#
#                                                          summary language  \
# work_id
# work_10057010  LONG fic charting the marauders' time at Hogwa...  English
# work_234222    It always rains for Draco Malfoy. Metaphorical...  English
# ...
