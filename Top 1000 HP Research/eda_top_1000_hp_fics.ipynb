# %% [markdown]
# # Exploratory Data Analysis of the Top 1000 Harry Potter Fanfictions on AO3

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import data
top_1000_hp_fics = pd.read_csv('top_1000_hp_fics_clean.csv')
hp_characters_bool = pd.read_csv('top_1000_hp_characters_bool.csv')
hp_fandoms_bool = pd.read_csv('top_1000_hp_fandoms_bool.csv')
hp_freeforms_bool = pd.read_csv('top_1000_hp_freeforms_bool.csv')
hp_relationships_bool = pd.read_csv('top_1000_hp_relationships_bool.csv')
hp_slash_categories_bool = pd.read_csv('top_1000_hp_slash_categories_bool.csv')
hp_warnings_bool = pd.read_csv('top_1000_hp_warnings_bool.csv')

# %%
# Make sure they all loaded in okay
print(top_1000_hp_fics.head())
print(hp_characters_bool.head())
print(hp_fandoms_bool.head())
print(hp_freeforms_bool.head())
print(hp_relationships_bool.head())
print(hp_slash_categories_bool.head())
print(hp_warnings_bool.head())
# Out:
#    Unnamed: 0        work_id       user_id  \
# 0           0  work_10057010  user-2878526
# 1           1    work_234222     user-6004
# 2           2  work_14454174  user-3861138
# 3           3   work_3101099   user-276513
# 4           4  work_12006417    user-53377
#
#                                   title                 rating  \
# 0                   All the Young Dudes                 Mature
# 1  Then Comes a Mist and a Weeping Rain               Explicit
# 2                              Manacled               Explicit
# 3            The Standard You Walk Past                 Mature
# 4                  survival is a talent  Teen And Up Audiences
#
#                                              summary language   words  \
# 0  LONG fic charting the marauders' time at Hogwa...  English  526969
# 1  It always rains for Draco Malfoy. Metaphorical...  English   21139
# 2  Harry Potter is dead. In the aftermath of the ...  English  370515
# ...
